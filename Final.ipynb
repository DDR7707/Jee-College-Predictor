# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Data/Extras/Final_2020_dataset.csv")
df
# Out:
#                                               Institute  \
# 0            Indian Institute of Technology Bhubaneswar
# 1            Indian Institute of Technology Bhubaneswar
# 2            Indian Institute of Technology Bhubaneswar
# 3            Indian Institute of Technology Bhubaneswar
# 4            Indian Institute of Technology Bhubaneswar
# ...                                                 ...
# 8788  North Eastern Regional Institute of Science an...
# 8789  North Eastern Regional Institute of Science an...
# 8790  North Eastern Regional Institute of Science an...
# 8791  North Eastern Regional Institute of Science an...
# 8792  North Eastern Regional Institute of Science an...
#
#                                   Academic Program Name Quota   Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI        OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI        OPEN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8793 entries, 0 to 8792
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Institute              8793 non-null   object
#  1   Academic Program Name  8793 non-null   object
#  2   Quota                  8793 non-null   object
#  3   Seat Type              8793 non-null   object
#  4   Gender                 8793 non-null   object
#  5   Opening Rank           8793 non-null   object
#  6   Closing Rank           8793 non-null   object
#  7   State                  8793 non-null   object
# dtypes: object(8)
# memory usage: 549.7+ KB

# %%
df["Institute"].unique()
# Out:
# array(['Indian Institute of Technology Bhubaneswar',
#        'Indian Institute of Technology Bombay',
#        'Indian Institute of Technology Mandi',
#        'Indian Institute of Technology Delhi',
#        'Indian Institute of Technology Indore',
#        'Indian Institute of Technology Kharagpur',
#        'Indian Institute of Technology Hyderabad',
#        'Indian Institute of Technology Jodhpur',
#        'Indian Institute of Technology Kanpur',
#        'Indian Institute of Technology Madras',
#        'Indian Institute of Technology Gandhinagar',
#        'Indian Institute of Technology Patna',
#        'Indian Institute of Technology Roorkee',
#        'Indian Institute of Technology (ISM) Dhanbad',
#        'Indian Institute of Technology Ropar',
#        'Indian Institute of Technology (BHU) Varanasi',
#        'Indian Institute of Technology Guwahati',
#        'Indian Institute of Technology Bhilai',
#        'Indian Institute of Technology Goa',
# ...

# %%
for i in df.columns:
    print(f"The number of unique values in {i} column is/are : {len(df[i].unique())}")
    print("\n")
    print(f"The unique values in {i} column is/are : {df[i].unique()}")
    print("\n")
    print(f"The value counts for each value in {i} column is/are :  \n{df[i].value_counts()}")
    print("\n")
    print(f"The number of missing values is/are : {df[i].isna().sum()}")
    print("\n\n")
    print("*"*100)
    print("\n\n")
# Out:
# The number of unique values in Institute column is/are : 110
#
#
# The unique values in Institute column is/are : ['Indian Institute of Technology Bhubaneswar'
#  'Indian Institute of Technology Bombay'
#  'Indian Institute of Technology Mandi'
#  'Indian Institute of Technology Delhi'
#  'Indian Institute of Technology Indore'
#  'Indian Institute of Technology Kharagpur'
#  'Indian Institute of Technology Hyderabad'
#  'Indian Institute of Technology Jodhpur'
#  'Indian Institute of Technology Kanpur'
#  'Indian Institute of Technology Madras'
#  'Indian Institute of Technology Gandhinagar'
#  'Indian Institute of Technology Patna'
#  'Indian Institute of Technology Roorkee'
#  'Indian Institute of Technology (ISM) Dhanbad'
#  'Indian Institute of Technology Ropar'
#  'Indian Institute of Technology (BHU) Varanasi'
#  'Indian Institute of Technology Guwahati'
#  'Indian Institute of Technology Bhilai'
#  'Indian Institute of Technology Goa'
# ...

# %%
college_sorter = ['Indian Institute of Technology Madras' ,
                  'Indian Institute of Technology Delhi' ,
                  'Indian Institute of Technology Bombay' ,
                  'Indian Institute of Technology Kanpur' ,                  
                  'Indian Institute of Technology Kharagpur' ,
                  'Indian Institute of Information Technology(IIIT) Kalyani, West Bengal' ,
                  'Indian Institute of Information Technology Lucknow' ,
                  'Indian Institute of Information Technology(IIIT) Dharwad' ,
                  'Indian Institute of Information Technology Bhagalpur' , 
                  'Indian Institute of Information Technology Bhopal' ,
                  'Indian Institute of Information Technology(IIIT) Kottayam' , 
                  'Indian Institute of Information Technology (IIIT) Ranchi' ,
                  'Indian Institute of Information Technology Surat' ,
                  'Indian Institute of Information Technology Manipur' ,
                  'Indian Institute of Information Technology Design & Manufacturing Kurnool, Andhra Pradesh' ,
                  'Indian Institute of Information Technology Srirangam, Tiruchirappalli' ,
                  'Indian Institute of Information Technology(IIIT) Kilohrad, Sonepat, Haryana' ,
                  'Indian Institute of Information Technology, Agartala' ,
                  'Indian institute of information technology, Raichur, Karnataka' ,
                  'Indian Institute of Information Technology(IIIT) Una, Himachal Pradesh' ,
                  'Assam University, Silchar' ,
                  'Gurukula Kangri Vishwavidyalaya, Haridwar' ,
                  'Indian Institute of Carpet Technology, Bhadohi' ,
                  'Institute of Infrastructure, Technology, Research and Management-Ahmedabad' ,
                  'Institute of Technology, Guru Ghasidas Vishwavidyalaya (A Central University), Bilaspur, (C.G.)' ,
                  'J.K. Institute of Applied Physics & Technology, Department of Electronics & Communication, University of Allahabad- Allahabad' ,
                  'National Institute of Electronics and Information Technology, Aurangabad (Maharashtra)' ,
                  'National Institute of Foundry & Forge Technology, Hatia, Ranchi' ,
                  'Sant Longowal Institute of Engineering and Technology' ,
                  'Mizoram University, Aizawl' ,
                  'School of Planning & Architecture, Bhopal' ,
                  'School of Planning & Architecture, New Delhi' ,
                  'School of Planning & Architecture: Vijayawada' ,
                  'Shri Mata Vaishno Devi University, Katra, Jammu & Kashmir' ,
                  'HNB Garhwal University Srinagar (Garhwal)' ,
                  'International Institute of Information Technology, Naya Raipur' ,
                  'International Institute of Information Technology, Bhubaneswar' ,
                  'Central institute of Technology Kokrajar, Assam' ,
                  'Ghani Khan Choudhary Institute of Engineering and Technology, Malda, West Bengal' ,
                  'Central University of Rajasthan, Rajasthan' ,
                  'National Institute of Food Technology Entrepreneurship and Management, Sonepat, Haryana' ,
                  'lndian Institute of Food Processing Technology, Thanjavur, Tamil Naidu.' ,
                  'North Eastern Regional Institute of Science and Technology, Nirjuli-791109 (Itanagar),Arunachal Pradesh']

# %%
for i in college_sorter :
    st = df["State"].loc[df["Institute"] == i].unique()[0]
    print(f"{i:50} -- {st}")
# Out:
# Indian Institute of Technology Madras              -- Tamil Nadu
# Indian Institute of Technology Delhi               -- Delhi
# Indian Institute of Technology Bombay              -- Maharashtra
# Indian Institute of Technology Kanpur              -- Uttar Pradesh
# Indian Institute of Technology Kharagpur           -- West Bengal
# Indian Institute of Technology Roorkee             -- Uttarakhand
# Indian Institute of Technology Guwahati            -- West Bengal
# Jawaharlal Nehru University, Delhi                 -- Delhi
# University of Hyderabad                            -- Telangana
# Indian Institute of Technology Hyderabad           -- Telangana
# National Institute of Technology, Tiruchirappalli  -- Tamil Nadu
# Indian Institute of Technology Indore              -- Madhya Pradesh
# Indian Institute of Technology (BHU) Varanasi      -- Uttar Pradesh
# Indian Institute of Technology (ISM) Dhanbad       -- Jharkhand
# ...

# %%
for i in df["Institute"]:
    if i not in college_sorter:
        print(i)

# %%
preparatory = []
for i in range(len(df["Closing Rank"])):
    if "P" in df["Closing Rank"].loc[i]:
        preparatory.append(i)
        
df_prep = df.loc[preparatory]
df_prep["Closing Rank"] = df_prep["Closing Rank"].apply(lambda x : x[:-1])
df_prep["Opening Rank"] = df_prep["Opening Rank"].apply(lambda x : x[:-1])
df_prep[["Opening Rank" , "Closing Rank"]] = df_prep[["Opening Rank" , "Closing Rank"]].apply(pd.to_numeric, errors='coerce')
df_prep
# Out:
#                                        Institute  \
# 2     Indian Institute of Technology Bhubaneswar
# 13    Indian Institute of Technology Bhubaneswar
# 40    Indian Institute of Technology Bhubaneswar
# 71    Indian Institute of Technology Bhubaneswar
# 74    Indian Institute of Technology Bhubaneswar
# ...                                          ...
# 2623        Indian Institute of Technology Jammu
# 2633      Indian Institute of Technology Dharwad
# 2643      Indian Institute of Technology Dharwad
# 2652      Indian Institute of Technology Dharwad
# 2653      Indian Institute of Technology Dharwad
#
#                                   Academic Program Name Quota   Seat Type  \
# 2     Civil Engineering (4 Years, Bachelor of Techno...    AI  OPEN (PwD)
# 13    Civil Engineering and M. Tech. in Structural E...    AI  OPEN (PwD)
# 40    Computer Science and Engineering (4 Years, Bac...    AI   EWS (PwD)
# 71    Electrical Engineering (4 Years, Bachelor of T...    AI          ST
# ...

# %%
# df_prep.to_csv("Data/Extras/Preperatory_2020_dataset.csv" , index = False)

# %%
df.drop(preparatory , inplace = True)
df = df.reset_index(drop = True)
df
# Out:
#                                               Institute  \
# 0            Indian Institute of Technology Bhubaneswar
# 1            Indian Institute of Technology Bhubaneswar
# 2            Indian Institute of Technology Bhubaneswar
# 3            Indian Institute of Technology Bhubaneswar
# 4            Indian Institute of Technology Bhubaneswar
# ...                                                 ...
# 8455  North Eastern Regional Institute of Science an...
# 8456  North Eastern Regional Institute of Science an...
# 8457  North Eastern Regional Institute of Science an...
# 8458  North Eastern Regional Institute of Science an...
# 8459  North Eastern Regional Institute of Science an...
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# ...

# %%
df.loc[df["Institute"] == "Dr. B R Ambedkar National Institute of Technology, Jalandhar"]
# Out:
#                                               Institute  \
# 2321  Dr. B R Ambedkar National Institute of Technol...
# 2322  Dr. B R Ambedkar National Institute of Technol...
# 2323  Dr. B R Ambedkar National Institute of Technol...
# 2324  Dr. B R Ambedkar National Institute of Technol...
# 2325  Dr. B R Ambedkar National Institute of Technol...
# ...                                                 ...
# 2541  Dr. B R Ambedkar National Institute of Technol...
# 2542  Dr. B R Ambedkar National Institute of Technol...
# 2543  Dr. B R Ambedkar National Institute of Technol...
# 2544  Dr. B R Ambedkar National Institute of Technol...
# 2545  Dr. B R Ambedkar National Institute of Technol...
#
#                                   Academic Program Name Quota Seat Type  \
# 2321   Bio Technology (4 Years, Bachelor of Technology)    HS      OPEN
# 2322   Bio Technology (4 Years, Bachelor of Technology)    HS      OPEN
# 2323   Bio Technology (4 Years, Bachelor of Technology)    HS       EWS
# ...

# %%
df.loc[2321]
# Out:
# Institute                Dr. B R Ambedkar National Institute of Technol...
# Academic Program Name     Bio Technology (4 Years, Bachelor of Technology)
# Quota                                                                   HS
# Seat Type                                                             OPEN
# Gender                                                      Gender-Neutral
# Opening Rank                                                         56242
# Closing Rank                                                         81305
# State                                                               Punjab
# Name: 2321, dtype: object

# %%
df_temp = df.loc[range(0 , 2321)]
df_temp
# Out:
#                                        Institute  \
# 0     Indian Institute of Technology Bhubaneswar
# 1     Indian Institute of Technology Bhubaneswar
# 2     Indian Institute of Technology Bhubaneswar
# 3     Indian Institute of Technology Bhubaneswar
# 4     Indian Institute of Technology Bhubaneswar
# ...                                          ...
# 2316      Indian Institute of Technology Dharwad
# 2317      Indian Institute of Technology Dharwad
# 2318      Indian Institute of Technology Dharwad
# 2319      Indian Institute of Technology Dharwad
# 2320      Indian Institute of Technology Dharwad
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 3     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# ...

# %%
df_temp[["Opening Rank" , "Closing Rank"]] = df_temp[["Opening Rank" , "Closing Rank"]].apply(pd.to_numeric, errors='coerce')

# %%
df_temp
# Out:
#                                        Institute  \
# 0     Indian Institute of Technology Bhubaneswar
# 1     Indian Institute of Technology Bhubaneswar
# 2     Indian Institute of Technology Bhubaneswar
# 3     Indian Institute of Technology Bhubaneswar
# 4     Indian Institute of Technology Bhubaneswar
# ...                                          ...
# 2316      Indian Institute of Technology Dharwad
# 2317      Indian Institute of Technology Dharwad
# 2318      Indian Institute of Technology Dharwad
# 2319      Indian Institute of Technology Dharwad
# 2320      Indian Institute of Technology Dharwad
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 3     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# ...

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2321 entries, 0 to 2320
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Institute              2321 non-null   object
#  1   Academic Program Name  2321 non-null   object
#  2   Quota                  2321 non-null   object
#  3   Seat Type              2321 non-null   object
#  4   Gender                 2321 non-null   object
#  5   Opening Rank           2321 non-null   int64
#  6   Closing Rank           2321 non-null   int64
#  7   State                  2321 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 163.2+ KB

# %%
# df_temp.to_csv("Data/Non_Prep_Adv_2020.csv" , index = False)

# %%
adv_rank = int(200)
mains_rank = int(12123)
cat = "OPEN"
prepare = False
gender = "Gender-Neutral"
state = "Odisha"

# %%
def only_adv(prepare , adv_rank , cat , gender , state):
    
    if prepare :
        final = df_prep.loc[(df_prep["Seat Type"] == cat) & (df_prep["Gender"] == gender) & (df_prep["Closing Rank"] >= adv_rank)].sort_values(by = ["Institute"] , ascending = [college_sorter]).reset_index(drop = True) 
        
    else:
        final = df.loc[(df["Seat Type"] == cat) & (df["Gender"] == gender) & (df["Closing Rank"] >= adv_rank)].sort_values(by = ["Institute"] , ascending = [college_sorter]).reset_index(drop = True)

# %%
df[["Opening Rank" , "Closing Rank"]] = df[["Opening Rank" , "Closing Rank"]].apply(pd.to_numeric, errors='coerce')

# %%
df
# Out:
#                                               Institute  \
# 0            Indian Institute of Technology Bhubaneswar
# 1            Indian Institute of Technology Bhubaneswar
# 2            Indian Institute of Technology Bhubaneswar
# 3            Indian Institute of Technology Bhubaneswar
# 4            Indian Institute of Technology Bhubaneswar
# ...                                                 ...
# 8455  North Eastern Regional Institute of Science an...
# 8456  North Eastern Regional Institute of Science an...
# 8457  North Eastern Regional Institute of Science an...
# 8458  North Eastern Regional Institute of Science an...
# 8459  North Eastern Regional Institute of Science an...
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8460 entries, 0 to 8459
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Institute              8460 non-null   object
#  1   Academic Program Name  8460 non-null   object
#  2   Quota                  8460 non-null   object
#  3   Seat Type              8460 non-null   object
#  4   Gender                 8460 non-null   object
#  5   Opening Rank           8460 non-null   int64
#  6   Closing Rank           8460 non-null   int64
#  7   State                  8460 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 528.9+ KB

# %%
df.loc[(df["Seat Type"] == cat) & (df["Gender"] == gender) & (df["Closing Rank"] >= adv_rank)].sort_values(by = ["Institute"] , ascending = [college_sorter]).reset_index(drop = True)
# Out:
#                                              Institute  \
# 0                            Assam University, Silchar
# 1                            Assam University, Silchar
# 2                            Assam University, Silchar
# 3                            Assam University, Silchar
# 4                            Assam University, Silchar
# ..                                                 ...
# 969  Visvesvaraya National Institute of Technology,...
# 970  Visvesvaraya National Institute of Technology,...
# 971  Visvesvaraya National Institute of Technology,...
# 972  Visvesvaraya National Institute of Technology,...
# 973  lndian Institute of Food Processing Technology...
#
#                                  Academic Program Name Quota Seat Type  \
# 0    Electronics and Communication Engineering (4 Y...    AI      OPEN
# 1    Computer Science and Engineering (4 Years, Bac...    HS      OPEN
# 2    Computer Science and Engineering (4 Years, Bac...    AI      OPEN
# ...
